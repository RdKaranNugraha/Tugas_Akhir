# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_theme(style="whitegrid")
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('Gyroscope.csv')
df.head(10)
# Out:
#      epoc (ms)         timestamp (+0700)  elapsed (s)  x-axis (deg/s)  \
# 0  1.610000e+12  2021-01-31T14:59:21.008         0.00           3.780
# 1  1.610000e+12  2021-01-31T14:59:21.048         0.04          -1.341
# 2  1.610000e+12  2021-01-31T14:59:21.088         0.08           1.280
# 3  1.610000e+12  2021-01-31T14:59:21.128         0.12           5.061
# 4  1.610000e+12  2021-01-31T14:59:21.168         0.16           9.146
# 5  1.610000e+12  2021-01-31T14:59:21.208         0.20           3.232
# 6  1.610000e+12  2021-01-31T14:59:21.248         0.24           1.220
# 7  1.610000e+12  2021-01-31T14:59:21.288         0.28           4.024
# 8  1.610000e+12  2021-01-31T14:59:21.328         0.32           2.378
# 9  1.610000e+12  2021-01-31T14:59:21.368         0.36          -0.427
#
#    y-axis (deg/s)  z-axis (deg/s)   actid  subid-gradeid positionid  \
# 0          -0.610          -1.341  Others              1         1G
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182607 entries, 0 to 182606
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0    epoc (ms)         182607 non-null  float64
#  1   timestamp (+0700)  182607 non-null  object
#  2   elapsed (s)        182607 non-null  float64
#  3   x-axis (deg/s)     182607 non-null  float64
#  4   y-axis (deg/s)     182607 non-null  float64
#  5   z-axis (deg/s)     182607 non-null  float64
#  6   actid              182607 non-null  object
#  7   subid-gradeid      182607 non-null  int64
#  8   positionid         182607 non-null  object
#  9   dicontinuityid     138482 non-null  float64
#  10  Unnamed: 10        0 non-null       float64
#  11  Unnamed: 11        0 non-null       float64
#  12  Unnamed: 12        0 non-null       float64
#  13  Unnamed: 13        44125 non-null   float64
# dtypes: float64(10), int64(1), object(3)
# memory usage: 19.5+ MB

# %%
df['timestamp (+0700)']=df['timestamp (+0700)']
print(df.dtypes)
# Out:
#  epoc (ms)           float64
# timestamp (+0700)     object
# elapsed (s)          float64
# x-axis (deg/s)       float64
# y-axis (deg/s)       float64
# z-axis (deg/s)       float64
# actid                 object
# subid-gradeid          int64
# positionid            object
# dicontinuityid       float64
# Unnamed: 10          float64
# Unnamed: 11          float64
# Unnamed: 12          float64
# Unnamed: 13          float64
# dtype: object

# %%
print('Waktu awal kolom elapsed adalah:', df['elapsed (s)'].min())
df.head()
# Out:
# Waktu awal kolom elapsed adalah: 0.0
#      epoc (ms)         timestamp (+0700)  elapsed (s)  x-axis (deg/s)  \
# 0  1.610000e+12  2021-01-31T14:59:21.008         0.00           3.780
# 1  1.610000e+12  2021-01-31T14:59:21.048         0.04          -1.341
# 2  1.610000e+12  2021-01-31T14:59:21.088         0.08           1.280
# 3  1.610000e+12  2021-01-31T14:59:21.128         0.12           5.061
# 4  1.610000e+12  2021-01-31T14:59:21.168         0.16           9.146
#
#    y-axis (deg/s)  z-axis (deg/s)   actid  subid-gradeid positionid  \
# 0          -0.610          -1.341  Others              1         1G
# 1         -11.037          -0.183  Others              1         1G
# 2          -9.939          -0.244  Others              1         1G
# 3           4.146           2.439  Others              1         1G
# 4          -3.902           2.805  Others              1         1G
#
#    dicontinuityid  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# ...

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df.astype(object), x='elapsed (s)', y='x-axis (deg/s)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df.astype(object), x='elapsed (s)', y='y-axis (deg/s)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df.astype(object), x='elapsed (s)', y='z-axis (deg/s)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df[df.actid=='Welding'], x='elapsed (s)', y='z-axis (deg/s)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df[df.actid=='Preparation'], x='elapsed (s)', y='z-axis (deg/s)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df[df.actid=='Grinding'], x='elapsed (s)', y='z-axis (deg/s)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df[df.actid=='Slag Cleaning'], x='elapsed (s)', y='z-axis (deg/s)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df[df.actid=='Others'], x='elapsed (s)', y='z-axis (deg/s)')

# %%
df.actid.value_counts()
# Out:
# Others           94369
# Welding          28520
# Preparation      25575
# Grinding         23893
# Slag Cleaning    10250
# Name: actid, dtype: int64

# %%
df[df.actid=='Preparation'].describe()
# Out:
#          epoc (ms)    elapsed (s)  x-axis (deg/s)  y-axis (deg/s)  \
# count  2.557500e+04  25575.000000    25575.000000    25575.000000
# mean   1.610055e+12   4443.394917        0.924147       -0.629460
# std    3.572179e+08   1697.986551       23.650672       47.715443
# min    1.610000e+12    729.000000     -255.122000     -902.378000
# 25%    1.610000e+12   3254.700000       -1.280000       -3.232000
# 50%    1.610000e+12   4525.400000        0.854000       -0.671000
# 75%    1.610000e+12   6369.700000        3.841000        4.268000
# max    1.612360e+12   7302.440000      266.707000      763.659000
#
#        z-axis (deg/s)  subid-gradeid  dicontinuityid  Unnamed: 10  \
# count    25575.000000   25575.000000         23400.0          0.0
# mean        -0.110433       3.744868             0.0          NaN
# std         23.948840       0.836858             0.0          NaN
# min       -548.659000       1.000000             0.0          NaN
# ...

# %%
df[df.actid=='Grinding'].describe()
# Out:
#          epoc (ms)    elapsed (s)  x-axis (deg/s)  y-axis (deg/s)  \
# count  2.389300e+04  23893.000000    23893.000000    23893.000000
# mean   1.610000e+12   4591.747916        0.634406       -0.870321
# std    0.000000e+00   1681.754074       22.272323       46.246342
# min    1.610000e+12    958.000000     -241.463000     -907.439000
# 25%    1.610000e+12   3626.880000       -3.963000       -6.646000
# 50%    1.610000e+12   5165.720000        0.732000       -0.732000
# 75%    1.610000e+12   5612.640000        5.854000        5.854000
# max    1.610000e+12   6952.440000      170.549000      764.207000
#
#        z-axis (deg/s)  subid-gradeid  dicontinuityid  Unnamed: 10  \
# count    23893.000000   23893.000000    20618.000000          0.0
# mean        -0.082906       3.588792        0.108303          NaN
# std         24.315466       1.031784        0.344100          NaN
# min       -289.329000       1.000000        0.000000          NaN
# ...

# %%
df[df.actid=='Welding'].describe()
# Out:
#          epoc (ms)    elapsed (s)  x-axis (deg/s)  y-axis (deg/s)  \
# count  2.852000e+04  28520.000000    28520.000000    28520.000000
# mean   1.610033e+12   3219.410599        0.764810       -0.923253
# std    2.775286e+08   2084.933138       26.985728       49.348132
# min    1.610000e+12    742.000000     -201.220000    -1315.061000
# 25%    1.610000e+12   1429.190000       -2.195000       -4.817000
# 50%    1.610000e+12   2977.340000        0.549000       -0.671000
# 75%    1.610000e+12   4627.450000        3.963000        3.232000
# max    1.612360e+12   7304.240000      360.366000     1133.719000
#
#        z-axis (deg/s)  subid-gradeid  dicontinuityid  Unnamed: 10  \
# count    28520.000000   28520.000000    16320.000000          0.0
# mean         0.355025       2.716690        2.073836          NaN
# std         24.757634       1.484292        1.603432          NaN
# min       -347.378000       1.000000        1.000000          NaN
# ...

# %%
df[df.actid=='Slag Cleaning'].describe()
# Out:
#          epoc (ms)    elapsed (s)  x-axis (deg/s)  y-axis (deg/s)  \
# count  1.025000e+04  10250.000000    10250.000000    10250.000000
# mean   1.610000e+12   3912.760878        0.750641       -0.560839
# std    0.000000e+00   1665.129007       30.923684       68.782483
# min    1.610000e+12    933.000000     -258.415000    -1210.305000
# 25%    1.610000e+12   3121.450000       -4.512000       -7.683000
# 50%    1.610000e+12   4147.920000        0.732000       -0.701500
# 75%    1.610000e+12   4698.350000        6.463000        8.476000
# max    1.610000e+12   6917.440000      265.549000     1079.817000
#
#        z-axis (deg/s)  subid-gradeid  dicontinuityid  Unnamed: 10  \
# count    10250.000000   10250.000000          8225.0          0.0
# mean         0.464452       3.407317             0.0          NaN
# std         33.613788       1.194535             0.0          NaN
# min       -432.866000       1.000000             0.0          NaN
# ...

# %%
df[df.actid=='Others'].describe()
# Out:
#          epoc (ms)    elapsed (s)  x-axis (deg/s)  y-axis (deg/s)  \
# count  9.436900e+04  94369.000000    94369.000000    94369.000000
# mean   1.610000e+12   3302.237277        0.577395       -0.797885
# std    0.000000e+00   2216.185865       33.462005       59.377799
# min    1.610000e+12      0.000000     -404.939000    -1152.195000
# 25%    1.610000e+12   1623.680000       -7.134000      -11.402000
# 50%    1.610000e+12   2762.360000        0.671000       -0.671000
# 75%    1.610000e+12   5722.760000        8.354000       10.549000
# max    1.610000e+12   7267.440000      616.585000     1167.744000
#
#        z-axis (deg/s)  subid-gradeid  dicontinuityid  Unnamed: 10  \
# count     94369.00000   94369.000000         69919.0          0.0
# mean          0.07350       3.222732             0.0          NaN
# std          38.78407       1.314411             0.0          NaN
# min        -553.90200       1.000000             0.0          NaN
# ...
