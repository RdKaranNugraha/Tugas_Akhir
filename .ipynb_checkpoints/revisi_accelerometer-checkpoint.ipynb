# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_theme(style="whitegrid")
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('Accelerometer.csv')
df.head(10)
# Out:
#      epoc (ms)         timestamp (+0700)  elapsed (s)  x-axis (g)  y-axis (g)  \
# 0  1.610000e+12  2021-01-29T13.39.03.039         0.00       0.526       0.214
# 1  1.610000e+12  2021-01-29T13.39.03.079         0.04       0.943       0.493
# 2  1.610000e+12  2021-01-29T13.39.03.119         0.08       0.949       0.396
# 3  1.610000e+12  2021-01-29T13.39.03.159         0.12       0.733       0.136
# 4  1.610000e+12  2021-01-29T13.39.03.199         0.16       0.754       0.316
# 5  1.610000e+12  2021-01-29T13.39.03.239         0.20       0.654       0.324
# 6  1.610000e+12  2021-01-29T13.39.03.279         0.24       0.671       0.314
# 7  1.610000e+12  2021-01-29T13.39.03.319         0.28       0.706       0.281
# 8  1.610000e+12  2021-01-29T13.39.03.359         0.32       0.689       0.228
# 9  1.610000e+12  2021-01-29T13.39.03.399         0.36       0.811       0.274
#
#    z-axis (g)        actid  subid-gradeid positionid  dicontinuityid  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182607 entries, 0 to 182606
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0    epoc (ms)         182607 non-null  float64
#  1   timestamp (+0700)  182607 non-null  object
#  2   elapsed (s)        182607 non-null  float64
#  3   x-axis (g)         182607 non-null  float64
#  4   y-axis (g)         182607 non-null  float64
#  5   z-axis (g)         182607 non-null  float64
#  6   actid              182607 non-null  object
#  7   subid-gradeid      182606 non-null  float64
#  8   positionid         182607 non-null  object
#  9   dicontinuityid     182607 non-null  int64
#  10  Unnamed: 10        0 non-null       float64
#  11  Unnamed: 11        1 non-null       float64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 16.7+ MB

# %%
df['timestamp (+0700)']=df['timestamp (+0700)']
print(df.dtypes)
# Out:
#  epoc (ms)           float64
# timestamp (+0700)     object
# elapsed (s)          float64
# x-axis (g)           float64
# y-axis (g)           float64
# z-axis (g)           float64
# actid                 object
# subid-gradeid        float64
# positionid            object
# dicontinuityid         int64
# Unnamed: 10          float64
# Unnamed: 11          float64
# dtype: object

# %%
print('Waktu awal kolom elapsed adalah:', df['elapsed (s)'].min())
df.head()
# Out:
# Waktu awal kolom elapsed adalah: 0.0
#      epoc (ms)         timestamp (+0700)  elapsed (s)  x-axis (g)  y-axis (g)  \
# 0  1.610000e+12  2021-01-29T13.39.03.039         0.00       0.526       0.214
# 1  1.610000e+12  2021-01-29T13.39.03.079         0.04       0.943       0.493
# 2  1.610000e+12  2021-01-29T13.39.03.119         0.08       0.949       0.396
# 3  1.610000e+12  2021-01-29T13.39.03.159         0.12       0.733       0.136
# 4  1.610000e+12  2021-01-29T13.39.03.199         0.16       0.754       0.316
#
#    z-axis (g)        actid  subid-gradeid positionid  dicontinuityid  \
# 0       0.646  Preparation            4.0         1G               0
# 1       0.487  Preparation            4.0         1G               0
# 2       0.625  Preparation            4.0         1G               0
# 3       0.405  Preparation            4.0         1G               0
# 4       0.521  Preparation            4.0         1G               0
#
#    Unnamed: 10  Unnamed: 11
# ...

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df.astype(object), x='elapsed (s)', y='x-axis (g)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df.astype(object), x='elapsed (s)', y='y-axis (g)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df.astype(object), x='elapsed (s)', y='z-axis (g)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df[df.actid=='Welding'], x='elapsed (s)', y='z-axis (g)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df[df.actid=='Preparation'], x='elapsed (s)', y='z-axis (g)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df[df.actid=='Grinding'], x='elapsed (s)', y='z-axis (g)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df[df.actid=='Slag Cleaning'], x='elapsed (s)', y='z-axis (g)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df[df.actid=='Others'], x='elapsed (s)', y='z-axis (g)')

# %%
print('--- [0] Welding \t\t:', df[df.actid=='Welding'].shape[0],'data')
# Out:
# --- [0] Welding 		: 24145 data

# %%
df.actid.value_counts()
# Out:
# Others           75794
# Preparation      35725
# Grinding         32318
# Welding          24145
# Slag Cleaning    14625
# Name: actid, dtype: int64

# %%
df[df.actid=='Preparation'].describe()
# Out:
#          epoc (ms)    elapsed (s)    x-axis (g)    y-axis (g)    z-axis (g)  \
# count  3.572500e+04  35725.000000  35725.000000  35725.000000  35725.000000
# mean   1.610000e+12   3384.678013      0.673799      0.310281      0.446415
# std    0.000000e+00   2230.582047      0.230394      0.256548      0.341110
# min    1.610000e+12      0.000000     -1.147000     -1.503000     -2.290000
# 25%    1.610000e+12   1305.240000      0.629000      0.210000      0.346000
# 50%    1.610000e+12   3386.440000      0.698000      0.328000      0.554000
# 75%    1.610000e+12   4968.600000      0.776000      0.428000      0.635000
# max    1.610000e+12   7302.440000      2.165000      2.893000      2.141000
#
#        subid-gradeid  dicontinuityid  Unnamed: 10  Unnamed: 11
# count        35724.0         35725.0          0.0          1.0
# mean             4.0             0.0          NaN          1.0
# std              0.0             0.0          NaN          NaN
# ...

# %%
df[df.actid=='Grinding'].describe()
# Out:
#          epoc (ms)    elapsed (s)    x-axis (g)    y-axis (g)    z-axis (g)  \
# count  3.231800e+04  32318.000000  32318.000000  32318.000000  32318.000000
# mean   1.610000e+12   3661.483599      0.641811      0.324996      0.430340
# std    0.000000e+00   2148.547868      0.238524      0.293776      0.353383
# min    1.610000e+12    302.000000     -1.327000     -1.916000     -2.230000
# 25%    1.610000e+12   1379.170000      0.533000      0.232000      0.281000
# 50%    1.610000e+12   3901.300000      0.679000      0.352000      0.534000
# 75%    1.610000e+12   5320.390000      0.774000      0.467000      0.662000
# max    1.610000e+12   6952.440000      1.985000      2.119000      2.446000
#
#        subid-gradeid  dicontinuityid  Unnamed: 10  Unnamed: 11
# count        32318.0    32318.000000          0.0          0.0
# mean             4.0        0.131042          NaN          NaN
# std              0.0        0.457902          NaN          NaN
# ...

# %%
df[df.actid=='Welding'].describe()
# Out:
#          epoc (ms)    elapsed (s)    x-axis (g)    y-axis (g)    z-axis (g)  \
# count  2.414500e+04  24145.000000  24145.000000  24145.000000  24145.000000
# mean   1.610000e+12   3437.209165      0.631826      0.346615      0.443711
# std    0.000000e+00   2239.018738      0.261764      0.328739      0.338924
# min    1.610000e+12    108.000000     -0.894000     -1.749000     -1.752000
# 25%    1.610000e+12   1451.440000      0.511000      0.222000      0.326000
# 50%    1.610000e+12   3442.840000      0.690000      0.405000      0.474000
# 75%    1.610000e+12   5066.200000      0.789000      0.493000      0.629000
# max    1.610000e+12   7304.240000      1.964000      2.880000      1.722000
#
#        subid-gradeid  dicontinuityid  Unnamed: 10  Unnamed: 11
# count        24145.0    24145.000000          0.0          0.0
# mean             4.0        1.872230          NaN          NaN
# std              0.0        1.416567          NaN          NaN
# ...

# %%
df[df.actid=='Slag Cleaning'].describe()
# Out:
#          epoc (ms)    elapsed (s)    x-axis (g)    y-axis (g)    z-axis (g)  \
# count  1.462500e+04  14625.000000  14625.000000  14625.000000  14625.000000
# mean   1.610000e+12   2961.553778      0.618927      0.347502      0.462334
# std    0.000000e+00   2028.748175      0.266405      0.323315      0.391173
# min    1.610000e+12    259.000000     -0.957000     -1.791000     -1.795000
# 25%    1.610000e+12   1094.240000      0.508000      0.210000      0.307000
# 50%    1.610000e+12   3136.440000      0.670000      0.360000      0.561000
# 75%    1.610000e+12   4515.640000      0.768000      0.500000      0.667000
# max    1.610000e+12   6917.440000      2.272000      2.692000      2.409000
#
#        subid-gradeid  dicontinuityid  Unnamed: 10  Unnamed: 11
# count        14625.0         14625.0          0.0          0.0
# mean             4.0             0.0          NaN          NaN
# std              0.0             0.0          NaN          NaN
# ...

# %%
df[df.actid=='Others'].describe()
# Out:
#          epoc (ms)    elapsed (s)    x-axis (g)    y-axis (g)    z-axis (g)  \
# count  7.579400e+04  75794.000000  75794.000000  75794.000000  75794.000000
# mean   1.610000e+12   3975.896359      0.521554      0.206394      0.345021
# std    0.000000e+00   1939.571092      0.339655      0.546349      0.405005
# min    1.610000e+12    171.000000     -1.978000     -2.080000     -1.984000
# 25%    1.610000e+12   2375.930000      0.249000      0.002000      0.083000
# 50%    1.610000e+12   3937.900000      0.576000      0.286000      0.329000
# 75%    1.610000e+12   5908.510000      0.781000      0.565000      0.645000
# max    1.610000e+12   7267.440000      2.805000      2.650000      2.568000
#
#        subid-gradeid  dicontinuityid  Unnamed: 10  Unnamed: 11
# count        75794.0         75794.0          0.0          0.0
# mean             4.0             0.0          NaN          NaN
# std              0.0             0.0          NaN          NaN
# ...

# %% [markdown]
# ### Modelling

# %%
train_size=int(len(df)*0.7)
train=df[:train_size]
test=df[train_size:].reset_index(drop=True)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(train[['z-axis (g)']])

train['scaled']=scaler.transform(train[['z-axis (g)']])
test['scaled']=scaler.transform(test[['z-axis (g)']])

# %%
train.head()
# Out:
#      epoc (ms)         timestamp (+0700)  elapsed (s)  x-axis (g)  y-axis (g)  \
# 0  1.610000e+12  2021-01-29T13.39.03.039         0.00       0.526       0.214
# 1  1.610000e+12  2021-01-29T13.39.03.079         0.04       0.943       0.493
# 2  1.610000e+12  2021-01-29T13.39.03.119         0.08       0.949       0.396
# 3  1.610000e+12  2021-01-29T13.39.03.159         0.12       0.733       0.136
# 4  1.610000e+12  2021-01-29T13.39.03.199         0.16       0.754       0.316
#
#    z-axis (g)        actid  subid-gradeid positionid  dicontinuityid  \
# 0       0.646  Preparation            4.0         1G               0
# 1       0.487  Preparation            4.0         1G               0
# 2       0.625  Preparation            4.0         1G               0
# 3       0.405  Preparation            4.0         1G               0
# 4       0.521  Preparation            4.0         1G               0
#
#    Unnamed: 10  Unnamed: 11    scaled
# 0          NaN          1.0  0.604364
# ...

# %%
def sliding_window(data, window_size):
    sub_seq, next_values = [], []
    for i in range(len(data)-window_size):
        sub_seq.append(data[i:i+window_size])
        next_values.append(data[i+window_size])
    X = np.stack(sub_seq)
    y = np.array(next_values)
    return X,y

# %%
window_size = 24

X_train, y_train = sliding_window(train[['scaled']].values, window_size)
X_test, y_test = sliding_window(test[['scaled']].values, window_size)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (127800, 24, 1) (127800, 1)
# (54759, 24, 1) (54759, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

# %%
def create_model(LSTM_unit=64, dropout=0.2): #jika ingin menggunakan RNN atau GRU ganti LSTM dengan GRU/RNN
    # create model
    model = Sequential()
    model.add(LSTM(units=LSTM_unit, input_shape=(window_size, 1)))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(dropout))
    model.add(Dense(1))
    # Compile model
    model.compile(loss='mse', optimizer='adam', metrics=['mae'])
    return model

# %%
LSTM_unit = [16,32,64,128]

# %%
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasRegressor
from keras.callbacks import EarlyStopping
# Early Stopping
es = EarlyStopping(monitor = 'val_loss', mode = "min", patience = 5, verbose = 0)

# create model
model = KerasRegressor(build_fn=create_model, epochs=50, validation_split=0.1, batch_size=32, callbacks=[es], verbose=1)

# define the grid search parameters
LSTM_unit = [16,32,64,128]
dropout=[0.1,0.2]
param_grid = dict(LSTM_unit=LSTM_unit, dropout=dropout)

# %%
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=5)

# %%
grid_result = grid.fit(X_train, y_train)

# %%
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
    
# Mengambil model terbaik
best_model = grid_result.best_estimator_.model
