# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_theme(style="whitegrid")
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('Magnetometer.csv')
df.head(10)
# Out:
#      epoc (ms)         timestamp (+0700)  elapsed (s)  x-axis (T)  y-axis (T)  \
# 0  1.610000e+12  2021-01-29T13.39.03.039         0.00    0.000021    0.000022
# 1  1.610000e+12  2021-01-29T13.39.03.079         0.04    0.000020    0.000022
# 2  1.610000e+12  2021-01-29T13.39.03.119         0.08    0.000021    0.000021
# 3  1.610000e+12  2021-01-29T13.39.03.159         0.12    0.000020    0.000023
# 4  1.610000e+12  2021-01-29T13.39.03.199         0.16    0.000020    0.000022
# 5  1.610000e+12  2021-01-29T13.39.03.239         0.20    0.000020    0.000022
# 6  1.610000e+12  2021-01-29T13.39.03.279         0.24    0.000020    0.000023
# 7  1.610000e+12  2021-01-29T13.39.03.319         0.28    0.000020    0.000023
# 8  1.610000e+12  2021-01-29T13.39.03.359         0.32    0.000020    0.000023
# 9  1.610000e+12  2021-01-29T13.39.03.399         0.36    0.000020    0.000024
#
#    z-axis (T)        actid  subid-gradeid positionid  dicontinuityid
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33667 entries, 0 to 33666
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0    epoc (ms)         33667 non-null  float64
#  1   timestamp (+0700)  33667 non-null  object
#  2   elapsed (s)        33667 non-null  float64
#  3   x-axis (T)         33667 non-null  float64
#  4   y-axis (T)         33667 non-null  float64
#  5   z-axis (T)         33666 non-null  float64
#  6   actid              33666 non-null  object
#  7   subid-gradeid      33666 non-null  float64
#  8   positionid         33666 non-null  object
#  9   dicontinuityid     33666 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 2.6+ MB

# %%
df['timestamp (+0700)']=df['timestamp (+0700)']
print(df.dtypes)
# Out:
#  epoc (ms)           float64
# timestamp (+0700)     object
# elapsed (s)          float64
# x-axis (T)           float64
# y-axis (T)           float64
# z-axis (T)           float64
# actid                 object
# subid-gradeid        float64
# positionid            object
# dicontinuityid       float64
# dtype: object

# %%
print('Waktu awal kolom elapsed adalah:', df['elapsed (s)'].min())
df.head()
# Out:
# Waktu awal kolom elapsed adalah: 0.0
#      epoc (ms)         timestamp (+0700)  elapsed (s)  x-axis (T)  y-axis (T)  \
# 0  1.610000e+12  2021-01-29T13.39.03.039         0.00    0.000021    0.000022
# 1  1.610000e+12  2021-01-29T13.39.03.079         0.04    0.000020    0.000022
# 2  1.610000e+12  2021-01-29T13.39.03.119         0.08    0.000021    0.000021
# 3  1.610000e+12  2021-01-29T13.39.03.159         0.12    0.000020    0.000023
# 4  1.610000e+12  2021-01-29T13.39.03.199         0.16    0.000020    0.000022
#
#    z-axis (T)        actid  subid-gradeid positionid  dicontinuityid
# 0    0.000003  Preparation            4.0         1G             0.0
# 1    0.000003  Preparation            4.0         1G             0.0
# 2    0.000003  Preparation            4.0         1G             0.0
# 3    0.000002  Preparation            4.0         1G             0.0
# 4    0.000002  Preparation            4.0         1G             0.0

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df.astype(object), x='elapsed (s)', y='x-axis (T)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df.astype(object), x='elapsed (s)', y='y-axis (T)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df.astype(object), x='elapsed (s)', y='z-axis (T)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df[df.actid=='Welding'], x='elapsed (s)', y='z-axis (T)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df[df.actid=='Preparation'], x='elapsed (s)', y='z-axis (T)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df[df.actid=='Grinding'], x='elapsed (s)', y='z-axis (T)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df[df.actid=='Slag Cleaning'], x='elapsed (s)', y='z-axis (T)')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df[df.actid=='Others'], x='elapsed (s)', y='z-axis (T)')

# %%
df.actid.value_counts()
# Out:
# Preparation      9966
# Grinding         8050
# Welding          5700
# Others           5000
# Slag Cleaning    4950
# Name: actid, dtype: int64

# %%
df[df.actid=='Preparation'].describe()
# Out:
#          epoc (ms)   elapsed (s)   x-axis (T)   y-axis (T)   z-axis (T)  \
# count  9.966000e+03  9966.000000  9966.000000  9966.000000  9966.000000
# mean   1.610000e+12   640.943388     0.000002     0.000024     0.000005
# std    0.000000e+00   469.478725     0.000016     0.000019     0.000018
# min    1.610000e+12     0.000000    -0.000137    -0.000124    -0.000027
# 25%    1.610000e+12    99.650000    -0.000009     0.000016    -0.000006
# 50%    1.610000e+12   496.300000     0.000006     0.000026     0.000000
# 75%    1.610000e+12   938.950000     0.000014     0.000035     0.000010
# max    1.610000e+12  1346.600000     0.000030     0.000087     0.000163
#
#        subid-gradeid  dicontinuityid
# count         9966.0          9966.0
# mean             4.0             0.0
# std              0.0             0.0
# min              4.0             0.0
# 25%              4.0             0.0
# 50%              4.0             0.0
# 75%              4.0             0.0
# ...

# %%
df[df.actid=='Grinding'].describe()
# Out:
#          epoc (ms)   elapsed (s)   x-axis (T)   y-axis (T)   z-axis (T)  \
# count  8.050000e+03  8050.000000  8050.000000  8050.000000  8050.000000
# mean   1.610000e+12   813.936522     0.000019     0.000027    -0.000004
# std    0.000000e+00   325.534838     0.000019     0.000018     0.000017
# min    1.610000e+12   302.000000    -0.000058    -0.000043    -0.000077
# 25%    1.610000e+12   382.490000     0.000009     0.000020    -0.000010
# 50%    1.610000e+12   806.980000     0.000021     0.000030    -0.000004
# 75%    1.610000e+12  1171.470000     0.000030     0.000037     0.000001
# max    1.610000e+12  1251.960000     0.000074     0.000067     0.000060
#
#        subid-gradeid  dicontinuityid
# count         8050.0     8050.000000
# mean             4.0        0.155155
# std              0.0        0.522236
# min              4.0        0.000000
# 25%              4.0        0.000000
# 50%              4.0        0.000000
# 75%              4.0        0.000000
# ...

# %%
df[df.actid=='Welding'].describe()
# Out:
#          epoc (ms)   elapsed (s)   x-axis (T)   y-axis (T)   z-axis (T)  \
# count  5.700000e+03  5700.000000  5700.000000  5700.000000  5700.000000
# mean   1.610000e+12   604.330877    -0.000014     0.000007     0.000012
# std    0.000000e+00   340.866076     0.000005     0.000014     0.000008
# min    1.610000e+12   108.000000    -0.000045    -0.000012    -0.000019
# 25%    1.610000e+12   164.990000    -0.000015    -0.000004     0.000006
# 50%    1.610000e+12   569.980000    -0.000014     0.000005     0.000012
# 75%    1.610000e+12   972.970000    -0.000012     0.000006     0.000018
# max    1.610000e+12  1029.960000     0.000015     0.000055     0.000031
#
#        subid-gradeid  dicontinuityid
# count         5700.0     5700.000000
# mean             4.0        1.329649
# std              0.0        0.608703
# min              4.0        1.000000
# 25%              4.0        1.000000
# 50%              4.0        1.000000
# 75%              4.0        2.000000
# ...

# %%
df[df.actid=='Slag Cleaning'].describe()
# Out:
#          epoc (ms)   elapsed (s)   x-axis (T)   y-axis (T)    z-axis (T)  \
# count  4.950000e+03  4950.000000  4950.000000  4950.000000  4.950000e+03
# mean   1.610000e+12   724.944646     0.000018     0.000024 -1.559279e-07
# std    0.000000e+00   331.875657     0.000021     0.000014  1.606048e-05
# min    1.610000e+12   259.000000    -0.000300    -0.000026 -9.762500e-05
# 25%    1.610000e+12   389.490000     0.000011     0.000018 -1.006300e-05
# 50%    1.610000e+12   700.980000     0.000020     0.000023 -1.562000e-06
# 75%    1.610000e+12  1096.470000     0.000029     0.000030  6.813000e-06
# max    1.610000e+12  1145.960000     0.000292     0.000123  5.512500e-05
#
#        subid-gradeid  dicontinuityid
# count         4950.0          4950.0
# mean             4.0             0.0
# std              0.0             0.0
# min              4.0             0.0
# 25%              4.0             0.0
# 50%              4.0             0.0
# 75%              4.0             0.0
# ...

# %%
df[df.actid=='Others'].describe()
# Out:
#          epoc (ms)   elapsed (s)   x-axis (T)   y-axis (T)    z-axis (T)  \
# count  5.000000e+03  5000.000000  5000.000000  5000.000000  5.000000e+03
# mean   1.610000e+12   538.865000     0.000006     0.000022  5.536898e-07
# std    0.000000e+00   325.809423     0.000020     0.000020  1.503033e-05
# min    1.610000e+12   171.000000    -0.000051    -0.000030 -9.612500e-05
# 25%    1.610000e+12   220.990000    -0.000007     0.000012 -8.812000e-06
# 50%    1.610000e+12   609.980000     0.000008     0.000022 -2.000000e-06
# 75%    1.610000e+12   659.970000     0.000018     0.000034  6.375000e-06
# max    1.610000e+12  1072.960000     0.000097     0.000072  7.156200e-05
#
#        subid-gradeid  dicontinuityid
# count         5000.0          5000.0
# mean             4.0             0.0
# std              0.0             0.0
# min              4.0             0.0
# 25%              4.0             0.0
# 50%              4.0             0.0
# 75%              4.0             0.0
# ...
